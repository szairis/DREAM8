# %%
cd ..
# Out:
# /Users/sakellarios/Documents/MD-PhD/5-Research/DREAM8/src

# %%
import numpy as np
import pandas as pd
import pydot
import utilities
import models
from synthetic import gen_cantone, gen_xu
from IPython.display import Image
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
oldprior = pd.read_csv('../dat/experimental/experimental_prior.csv', index_col=0, header=0)

# %%
reload(utilities)
reload(models)
# Out:
# <module 'models' from 'models.py'>

# %%
bt20 = pd.read_csv('../dat/experimental/CSV/BT20_main.csv')
bt549 = pd.read_csv('../dat/experimental/CSV/BT549_main.csv')
mcf7 = pd.read_csv('../dat/experimental/CSV/MCF7_main.csv')
uacc812 = pd.read_csv('../dat/experimental/CSV/UACC812_main.csv')

# %%
bt20_all = bt20[bt20['Inhibitor'] == 'DMSO'].groupby(['Stimulus','Timepoint']).mean()
bt20_egf = bt20[(bt20['Stimulus'] == 'EGF') & (bt20['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt20_fgf1 = bt20[(bt20['Stimulus'] == 'FGF1') & (bt20['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt20_hgf = bt20[(bt20['Stimulus'] == 'HGF') & (bt20['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt20_igf1 = bt20[(bt20['Stimulus'] == 'IGF1') & (bt20['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt20_insulin = bt20[(bt20['Stimulus'] == 'Insulin') & (bt20['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt20_nrg1 = bt20[(bt20['Stimulus'] == 'NRG1') & (bt20['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt20_pbs = bt20[(bt20['Stimulus'] == 'PBS') & (bt20['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt20_serum = bt20[(bt20['Stimulus'] == 'Serum') & (bt20['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()

bt549_all = bt549[bt549['Inhibitor'] == 'DMSO'].groupby(['Stimulus','Timepoint']).mean()
bt549_egf = bt549[(bt549['Stimulus'] == 'EGF') & (bt549['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt549_fgf1 = bt549[(bt549['Stimulus'] == 'FGF1') & (bt549['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt549_hgf = bt549[(bt549['Stimulus'] == 'HGF') & (bt549['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt549_igf1 = bt549[(bt549['Stimulus'] == 'IGF1') & (bt549['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt549_insulin = bt549[(bt549['Stimulus'] == 'Insulin') & (bt549['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt549_nrg1 = bt549[(bt549['Stimulus'] == 'NRG1') & (bt549['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt549_pbs = bt549[(bt549['Stimulus'] == 'PBS') & (bt549['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
bt549_serum = bt549[(bt549['Stimulus'] == 'Serum') & (bt549['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()

mcf7_all = mcf7[mcf7['Inhibitor'] == 'DMSO'].groupby(['Stimulus','Timepoint']).mean()
mcf7_egf = mcf7[(mcf7['Stimulus'] == 'EGF') & (mcf7['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
mcf7_fgf1 = mcf7[(mcf7['Stimulus'] == 'FGF1') & (mcf7['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
mcf7_hgf = mcf7[(mcf7['Stimulus'] == 'HGF') & (mcf7['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
mcf7_igf1 = mcf7[(mcf7['Stimulus'] == 'IGF1') & (mcf7['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
mcf7_insulin = mcf7[(mcf7['Stimulus'] == 'Insulin') & (mcf7['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
mcf7_nrg1 = mcf7[(mcf7['Stimulus'] == 'NRG1') & (mcf7['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
mcf7_pbs = mcf7[(mcf7['Stimulus'] == 'PBS') & (mcf7['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
mcf7_serum = mcf7[(mcf7['Stimulus'] == 'Serum') & (mcf7['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()

uacc812_all = uacc812[uacc812['Inhibitor'] == 'DMSO'].groupby(['Stimulus','Timepoint']).mean()
uacc812_egf = uacc812[(uacc812['Stimulus'] == 'EGF') & (uacc812['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
uacc812_fgf1 = uacc812[(uacc812['Stimulus'] == 'FGF1') & (uacc812['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
uacc812_hgf = uacc812[(uacc812['Stimulus'] == 'HGF') & (uacc812['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
uacc812_igf1 = uacc812[(uacc812['Stimulus'] == 'IGF1') & (uacc812['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
uacc812_insulin = uacc812[(uacc812['Stimulus'] == 'Insulin') & (uacc812['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
uacc812_nrg1 = uacc812[(uacc812['Stimulus'] == 'NRG1') & (uacc812['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
uacc812_pbs = uacc812[(uacc812['Stimulus'] == 'PBS') & (uacc812['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()
uacc812_serum = uacc812[(uacc812['Stimulus'] == 'Serum') & (uacc812['Inhibitor'] == 'DMSO')].groupby('Timepoint').mean()

# %%
A_true_bt20 = oldprior
A_true_bt549 = A_true_bt20.ix[bt549_egf.columns, bt549_egf.columns]
A_true_mcf7 = A_true_bt20.ix[mcf7_egf.columns, mcf7_egf.columns]
A_true_uacc812 = A_true_bt20.ix[uacc812_egf.columns, uacc812_egf.columns]

# %%
prior = A_true_uacc812.values
lam = np.arange(0,10,0.5)
(ep, es) = models.network_hill(uacc812_serum, prior_graph=prior, lambdas=lam)
# Out:
# Starting MATLAB on http://localhost:59655
#  visit http://localhost:59655/exit.m to shut down same
# .
# .
# MATLAB started and connected!
# MATLAB closed

# %%
path = '../subchallenge1/submission4/sakev-Network/sakev-UACC812-Serum-Network'
utilities.write_SIF_EDA(ep, path)
#utilities.plot_adjacency_matrix(ep)

# %%
bt20_insulin.index
# Out:
# Int64Index([0, 5, 15, 30, 120, 240], dtype=int64)

# %%
for cutoff in [0.93, 0.96, 0.99]:
    A_bt20 = pd.DataFrame(np.zeros((46,46)), index=bt20_egf.columns, columns=bt20_egf.columns)
    A_dict = models.network_lasso(bt20, response_type='level')
    for key in A_dict:
        A_tmp = A_dict[key]
        A_tmp[A_tmp < cutoff] = 0
        A_tmp[A_tmp >= cutoff] = 1
        A_bt20 = np.logical_or(A_bt20, A_tmp)
    score = utilities.score_network(A_bt20, A_true_bt20)
    print 'CUTOFF: {0} and AUC: {1}'.format(cutoff, score)
# Out:
# CUTOFF: 0.93 and AUC: 0.631796337595
# CUTOFF: 0.96 and AUC: 0.632346012501
# CUTOFF: 0.99 and AUC: 0.633374689826

# %%
A_dict, auc_dict = models.network_lasso(bt549, response_type='level', ground_truth=A_true_bt549)
print 'BT549'
print '-------------------------------'
for key in auc_dict:
    print key, 'AUC:', auc_dict[key]
print '\n'
    
A_dict, auc_dict = models.network_lasso(mcf7, response_type='level', ground_truth=A_true_mcf7)
print 'MCF7'
print '-------------------------------'
for key in auc_dict:
    print key, 'AUC:', auc_dict[key]
print '\n'
    
A_dict, auc_dict = models.network_lasso(uacc812, response_type='level', ground_truth=A_true_uacc812)
print 'UACC812'
print '-------------------------------'
for key in auc_dict:
    print key, 'AUC:', auc_dict[key]

# %%
cutoff = 0.99
time_points = [0,5,15,30,60,120,240]
A_truth, TC_xu = gen_xu(time_points, EGF=10, Cilostamide=10, EPACA=10, Gap=10, PKAA=1000)
A_dict = models.network_lasso(TC_xu, response_type='level')
for key in A_dict:
    A_xu_tmp = A_dict[key]
    A_xu_tmp[A_tmp < cutoff] = 0
    A_xu_tmp[A_tmp >= cutoff] = 1
    A_xu = np.logical_or(A_xu_tmp, A_xu)

# %%
#utilities.plot_adjacency_matrix(A_xu)
#g = utilities.plot_network(Ainf, Ainf, 'Xu Inferred', 0.2)
#Image(g.create_png())

# %%
#A_xu = pd.DataFrame(np.zeros((16,16)), index=A_truth.columns, columns=A_truth.columns)
score = utilities.score_network(A_xu, A_truth)
print 'CUTOFF: {0} and AUC: {1}'.format(cutoff, score)
# Out:
# CUTOFF: 0.99 and AUC: 0.540750610704

# %%
TC_insilico = pd.read_csv('../dat/insilico/CSV/insilico.csv')
inhib_TC_insilico = utilities.introduce_inhibs(TC_insilico, {'INH1':'AB12', 'INH2':'AB05', 'INH3':'AB08'})

# %%
Ainf = models.network_lasso(TC_insilico)

# %%
Ainh = models.network_lasso(inhib_TC_insilico)

# %%
A_final = pd.DataFrame(np.zeros((23,23)), index=Ainh['hiLIG2'].columns, columns=Ainh['hiLIG2'].columns)

# %%
cutoff = 0.2
for key in Ainh:
    A_tmp = Ainh[key].copy()
    A_tmp[A_tmp < cutoff] = 0.0
    A_tmp[A_tmp >= cutoff] = 1.0
    A_final = A_final + A_tmp

# %%
A_final = A_final / np.max(A_final.values)
utilities.plot_adjacency_matrix(A_final)

# %%
A_final2 = pd.DataFrame(np.zeros((20,20)), index=TC_insilico.columns[4:], columns=TC_insilico.columns[4:])

# %%
cutoff2 = 0.2
for key in Ainf:
    A_tmp = Ainf[key].copy()
    A_tmp[A_tmp < cutoff2] = 0.0
    A_tmp[A_tmp >= cutoff2] = 1.0
    A_final2 = A_final2 + A_tmp

# %%
A_final2 = A_final2 / np.max(A_final2.values)
utilities.plot_adjacency_matrix(A_final2)

# %%
A_final_inh = A_final.ix[A_final2.columns, A_final2.columns]

# %%
np.shape(A_final_inh)
# Out:
# (20, 20)

# %%
A_final_noinh = A_final2

# %%
np.shape(A_final_noinh)
# Out:
# (20, 20)

# %%
A_final_final = 0.5 * (A_final_inh + A_final_noinh)

# %%
#hist(A_final_final.values)
#A_final_final[A_final_final < 0.5] = 0
#A_final_final[A_final_final >= 0.5] = 1
utilities.plot_adjacency_matrix(A_final_final)

# %%
A_final_final.ix['AB05', 'AB17'] = 1

# %%
path = '../subchallenge1/sakev-Network-Insilico'
utilities.write_SIF_EDA(A_final_final, path)
