# %%
import pandas as pd
df1 = pd.read_csv('./submission1/sakev-Prediction-Insilico/sakev-AB1-Prediction-Insilico.csv')
df2 = pd.read_csv('./submission3b/sakev-Prediction-Insilico/sakev-AB1-Prediction-Insilico.csv')

# %%
df1.columns
# Out:
# Index([u'TR:inSilico:CellLine', u'TR:loLIG1:Stimuli', u'TR:hiLIG1:Stimuli', u'TR:loLIG2:Stimuli', u'TR:hiLIG2:Stimuli', u'TR:loLIG1_loLIG2:Stimuli', u'TR:loLIG1_hiLIG2:Stimuli', u'TR:hiLIG1_loLIG2:Stimuli', u'TR:hiLIG1_hiLIG2:Stimuli', u'DA:ALL', u'DV:AB1', u'DV:AB2', u'DV:AB3', u'DV:AB4', u'DV:AB5', u'DV:AB6', u'DV:AB7', u'DV:AB8', u'DV:AB9', u'DV:AB10', u'DV:AB11', u'DV:AB12', u'DV:AB13', u'DV:AB14', u'DV:AB15', u'DV:AB16', u'DV:AB17', u'DV:AB18', u'DV:AB19', u'DV:AB20'], dtype=object)

# %%
df2.columns
# Out:
# Index([u'TR:inSilico:CellLine', u'TR:loLIG1:Stimuli', u'TR:hiLIG1:Stimuli', u'TR:loLIG2:Stimuli', u'TR:hiLIG2:Stimuli', u'TR:loLIG1_loLIG2:Stimuli', u'TR:loLIG1_hiLIG2:Stimuli', u'TR:hiLIG1_loLIG2:Stimuli', u'TR:hiLIG1_hiLIG2:Stimuli', u'DA:ALL', u'DV:AB1', u'DV:AB2', u'DV:AB3', u'DV:AB4', u'DV:AB5', u'DV:AB6', u'DV:AB7', u'DV:AB8', u'DV:AB9', u'DV:AB10', u'DV:AB11', u'DV:AB12', u'DV:AB13', u'DV:AB14', u'DV:AB15', u'DV:AB16', u'DV:AB17', u'DV:AB18', u'DV:AB19', u'DV:AB20'], dtype=object)

# %%
df1.columns==df2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True], dtype=bool)

# %%
columns = df1.columns
(df1[columns[:10]]==df2[columns[:10]]).values
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
df1[columns[10]],df1[columns[10]]
# Out:
# (0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# ...
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   NaN
# Name: DV:AB1, Length: 80, dtype: float64,
#  0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# ...
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   NaN
# Name: DV:AB1, Length: 80, dtype: float64)
